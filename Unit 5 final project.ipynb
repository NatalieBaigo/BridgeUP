# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#this is new variables for our brain
b_volume=25
femur=295
O_bulb=8
Cere_brum=38
O_lobes=29
Cere_bellum=13

# %%
#this is our body mass for OUR brain
ourbrain= O_bulb+ Cere_brum+ O_lobes+ Cere_bellum
print(ourbrain)
mass=10**(3.1854*np.log10(femur)-3.184)/1000
print(mass)
# Out:
# 88
# 48.23597370021272

# %%
#find the brain to body mass
brain_body= b_volume/(mass*1000)
#find the cerebrum to brain ratio
cereb_brain= Cere_brum/ourbrain

# %%
print(brain_body)
print(cereb_brain)
# Out:
# 0.0005182853808523773
# 0.4318181818181818

# %%
df= pd.read_csv("bird_dino_data.csv")

# %%
df.head(25)
# Out:
#     Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 0            1            B            0.02                  0.009
# 1            2            B            1.26                  0.006
# 2            3            B            2.18                  0.026
# 3            4            D            0.25                  0.050
# 4            5            B            0.01                  0.003
# 5            6            D           85.96                  0.569
# 6            7            D            0.50                  0.077
# 7            8            B            0.90                  0.234
# 8            9            B            0.26                  0.027
# 9           10            D           12.61                  0.028
# 10          11            B            0.17                  0.015
# 11          12            B            0.43                  0.206
# 12          13            B            0.05                  0.008
# ...

# %%
#make a new column for the whole brain ratio
df["Whole brain"]= df["Olfactory bulbs (cm3)"]
+ df["Cerebrum (cm3)"]+ df["Optic Lobes (cm3)"]+ df["Cerebellum (cm3)"]
df.head()
# Out:
#    Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 0           1            B            0.02                  0.009
# 1           2            B            1.26                  0.006
# 2           3            B            2.18                  0.026
# 3           4            D            0.25                  0.050
# 4           5            B            0.01                  0.003
#
#    Cerebrum (cm3)  Optic Lobes (cm3)  Cerebellum (cm3)  Brain Stem (cm3)  \
# 0            1.53               0.20              0.16              0.06
# 1           16.81               2.84              1.70              0.68
# 2           11.08               1.95              0.89              1.15
# 3            0.41               0.16              0.09              0.12
# 4            1.57               0.20              0.34              0.08
#
#    Whole brain  Brain to Body Mass  Cerebrum to Brain
# 0        0.009            0.094950           0.805687
# ...

# %%
#find average brain/body mass and cerebrum/whole body for your brain and find averagebrain/body mass and 
#cerebrum/whole  body for birds vs. non-avian birds
brain=df["Whole brain"]
body=df["Body Mass (kg)"]
df["Brain to Body Mass"]=brain/(body*1000)
df.head()
# Out:
#    Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 0           1            B            0.02                  0.009
# 1           2            B            1.26                  0.006
# 2           3            B            2.18                  0.026
# 3           4            D            0.25                  0.050
# 4           5            B            0.01                  0.003
#
#    Cerebrum (cm3)  Optic Lobes (cm3)  Cerebellum (cm3)  Brain Stem (cm3)  \
# 0            1.53               0.20              0.16              0.06
# 1           16.81               2.84              1.70              0.68
# 2           11.08               1.95              0.89              1.15
# 3            0.41               0.16              0.09              0.12
# 4            1.57               0.20              0.34              0.08
#
#    Whole brain  Brain to Body Mass
# 0        1.899            0.094950
# 1       21.356            0.016949
# ...

# %%
cerebrum=df["Cerebrum (cm3)"]
df["Cerebrum to Brain"]= cerebrum/brain
df.head()
# Out:
#    Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 0           1            B            0.02                  0.009
# 1           2            B            1.26                  0.006
# 2           3            B            2.18                  0.026
# 3           4            D            0.25                  0.050
# 4           5            B            0.01                  0.003
#
#    Cerebrum (cm3)  Optic Lobes (cm3)  Cerebellum (cm3)  Brain Stem (cm3)  \
# 0            1.53               0.20              0.16              0.06
# 1           16.81               2.84              1.70              0.68
# 2           11.08               1.95              0.89              1.15
# 3            0.41               0.16              0.09              0.12
# 4            1.57               0.20              0.34              0.08
#
#    Whole brain  Brain to Body Mass  Cerebrum to Brain
# 0        1.899            0.094950           0.805687
# ...

# %%
#find the average of each
df_B=df.loc[df["Bird vs Dino"]=="B"]
df_B.head()
# Out:
#    Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 0           1            B            0.02                  0.009
# 1           2            B            1.26                  0.006
# 2           3            B            2.18                  0.026
# 4           5            B            0.01                  0.003
# 7           8            B            0.90                  0.234
#
#    Cerebrum (cm3)  Optic Lobes (cm3)  Cerebellum (cm3)  Brain Stem (cm3)  \
# 0            1.53               0.20              0.16              0.06
# 1           16.81               2.84              1.70              0.68
# 2           11.08               1.95              0.89              1.15
# 4            1.57               0.20              0.34              0.08
# 7            5.95               0.99              0.96              0.55
#
#    Whole brain  Brain to Body Mass  Cerebrum to Brain
# 0        1.899            0.094950           0.805687
# ...

# %%
df_B.mean()
# Out:
# Species ID               13.388889
# Body Mass (kg)            3.932222
# Olfactory bulbs (cm3)     0.055556
# Cerebrum (cm3)            7.682778
# Optic Lobes (cm3)         1.436667
# Cerebellum (cm3)          1.371111
# Brain Stem (cm3)          0.781667
# Whole brain              10.546111
# Brain to Body Mass        0.045170
# Cerebrum to Brain         0.709443
# dtype: float64

# %%
cb_bird= df_B["Cerebrum to Brain"].mean()
print(cb_bird)
bb_bird= df_B["Brain to Body Mass"].mean()
print(bb_bird)
# Out:
# 0.7094430277327214
# 0.045170238698633944

# %%
df_D=df.loc[df["Bird vs Dino"]=="D"]
df_D.head()
# Out:
#     Species ID Bird vs Dino  Body Mass (kg)  Olfactory bulbs (cm3)  \
# 3            4            D            0.25                  0.050
# 5            6            D           85.96                  0.569
# 6            7            D            0.50                  0.077
# 9           10            D           12.61                  0.028
# 14          15            D           49.30                  1.080
#
#     Cerebrum (cm3)  Optic Lobes (cm3)  Cerebellum (cm3)  Brain Stem (cm3)  \
# 3             0.41               0.16              0.09              0.12
# 5             9.52               3.60              5.16              3.78
# 6             0.60               0.36              0.24              0.17
# 9             3.71               1.31              1.60              2.17
# 14           14.81               4.75              3.16              2.35
#
#     Whole brain  Brain to Body Mass  Cerebrum to Brain
# 3         0.710            0.002840           0.577465
# ...

# %%
df_D.mean()
# Out:
# Species ID               12.000000
# Body Mass (kg)           23.641429
# Olfactory bulbs (cm3)     0.266714
# Cerebrum (cm3)            4.577143
# Optic Lobes (cm3)         1.678571
# Cerebellum (cm3)          1.580000
# Brain Stem (cm3)          1.331429
# Whole brain               8.102429
# Brain to Body Mass        0.001400
# Cerebrum to Brain         0.547934
# dtype: float64

# %%
cb_dino=df_D["Cerebrum to Brain"].mean()
print(cb_dino)
bb_dino=df_D["Brain to Body Mass"].mean()
print(bb_dino)
# Out:
# 0.5479339483969496
# 0.0014002983908859297

# %%
#measurements, reference data set info about birds + non avian Dino brains
#REACH GOAL: make a function that uses femur length, brain volume, cerebrum width, whole brain width
#return: bird! or non avian Dino  
Cere_brum=38
ourbrain=88
def cerebrumcheck(cerebrum,wholebrain):
    cereb_brain= Cere_brum/ourbrain
    cb_dino=df_D["Cerebrum to Brain"].mean()
    cb_bird=df_B["Cerebrum to Brain"].mean()
    if abs(cereb_brain-cb_dino)> abs(cereb_brain-cb_bird):
        word_f = "Bird!"
    elif abs(cereb_brain-cb_bird)> abs(cereb_brain-cb_dino):
        word_f ="Non Avian Dino"
    return word_f

# %%
print(cerebrumcheck(Cere_brum,ourbrain))
# Out:
# Non Avian Dino

# %%
def braincheck(cerebrum,wholebrain):
    cereb_brain=Cere_brum/ourbrain
    if abs(brain_body-bb_dino)> abs(brain_body-bb_bird):
        word_f="Bird!"
    elif abs(brain_body-bb_bird)> abs(brain_body-bb_dino):
        word_f="Non Avian Dino"
    return word_f

# %%
print(braincheck(Cere_brum,ourbrain))
# Out:
# Non Avian Dino
